# %% [markdown]
# # Ontario sunshine list 2021

# %% [markdown]
# The sunshine list is here for 2021, and I put together some graphics for CBC News breaking down what's in it this year.
#
# First, let's import pandas and a few other modules I'll use in the analysis.

# %%
import pandas as pd
import numpy as np
import math
import requests
import json

# %% [markdown]
# We're going to be looking at a lot of float values, so I'll take the time here to set a global format for them all.

# %%
pd.options.display.float_format = '{:,}'.format

# %% [markdown]
# Now we read in the data, downloaded [here](https://www.ontario.ca/public-sector-salary-disclosure/2021/all-sectors-and-seconded-employees/).

# %%
raw_2021 = pd.read_csv('./raw/2021.csv', encoding="utf-8", encoding_errors='ignore', thousands=',')

# %% [markdown]
# Because we'll do a lot of analysis with this raw file, I'm going to make a copy and call it "data".

# %%
data = raw_2021.copy()

# %% [markdown]
# Then, we'll do a bit of cleaning. We'll create a new column called "name" that is the first and last name combined.

# %%
data["Name"] = data["First Name"] + " " + data["Last Name"]

# %% [markdown]
# Then, we slice off the French title from the "job title" column, which is usually separated by a slash (forward or back).

# %%
data["Job Title"] = data["Job Title"].apply(lambda x: x.split("/|\\")[0].strip())

# %% [markdown]
# We're also going to remove the "seconded" sectors, because they don't look all that interesting.

# %%
data = (data
        .loc[~data["Sector"].str.contains("Second"), :]
        .sort_values('Salary', ascending=False)
        .set_index("Name")
        )

# %% [markdown]
# Next, we're going to bin the data into various earning groups. We do this semi-programmatically by finding max and min values, then using a numpy function to split the range into equal parts.

# %%
# Binning into brackets
min_value = data['Salary'].min()
max_value = data['Salary'].max()

bins = np.linspace(min_value,320000,5)

for i, number in enumerate(bins, 0):
    bins[i] = round(number, -3)
    
bins = np.append(bins, round(math.ceil(max_value/100000)*100000, -5))

# %% [markdown]
# Now we piece together some nicer labels for each of the bins, and then run the `pd.cut()` method to actually do the binning.

# %%
labels = []

for i, number in enumerate(bins, 0):
    try:
        label = "$" + '{:,}'.format(round(bins[i])) + " - $" + '{:,}'.format(round(bins[i+1]))
        labels.append(label)
    except:
        print()
    
data["Earnings Bracket"] = pd.cut(data['Salary'], bins=bins, labels=labels, include_lowest=True).str.replace("00,000", "M").str.replace(",000", "K").str.replace(",", ".").str.replace("1M", "100K")

# %% [markdown]
# Now let's take a peek at how it looks.

# %%
data.head(5)
# Out:
#                                                 Sector  Last Name First Name  \
# Name
# Kenneth Hartwick              Ontario Power Generation   Hartwick    Kenneth
# Dominique Miniere             Ontario Power Generation    Miniere  Dominique
# Sean Granville                Ontario Power Generation  Granville       Sean
# Michael Martelli              Ontario Power Generation   Martelli    Michael
# Kevin Smith        Hospitals & Boards of Public Health      Smith      Kevin
#
#                         Salary  Benefits                   Employer  \
# Name
# Kenneth Hartwick   1,628,246.0  7,539.84   Ontario Power Generation
# Dominique Miniere 1,523,518.84  3,922.56   Ontario Power Generation
# Sean Granville    1,064,429.42  2,632.32   Ontario Power Generation
# Michael Martelli  1,010,834.05   3,758.4   Ontario Power Generation
# Kevin Smith          845,092.2 87,153.64  University Health Network
#
#                                                            Job Title  Year  \
# Name
# Kenneth Hartwick               President and Chief Executive Officer  2021
# Dominique Miniere                             Chief Strategy Officer  2021
# Sean Granville     Chief Operations Officer and Chief Nuclear Off...  2021
# Michael Martelli                              Chief Projects Officer  2021
# Kevin Smith                    President and Chief Executive Officer  2021
#
#                    _docID Earnings Bracket
# Name
# Kenneth Hartwick   126612    $320K - $1.7M
# Dominique Miniere  128750    $320K - $1.7M
# Sean Granville     126360    $320K - $1.7M
# Michael Martelli   128308    $320K - $1.7M
# Kevin Smith         64694    $320K - $1.7M

# %% [markdown]
# From here, we'll do a variety of analyses on this now (pretty) clean dataset.

# %% [markdown]
# ### Employer totals

# %% [markdown]
# First, a quick look at the totals for each employer, just to get a sense of the big players here.

# %%
data.pivot_table(index="Employer", values="Salary", aggfunc="sum").sort_values("Salary", ascending=False)
# Out:
#                                                              Salary
# Employer
# Ontario Power Generation                           1,284,854,409.88
# Toronto District School Board                       1,125,152,992.1
# City Of Toronto                                      914,069,833.63
# University Of Toronto                                806,686,517.09
# Ontario Provincial Police                            701,360,163.01
# ...                                                             ...
# Pwi-di-goo-zing-ne-yaa-zhing Advisory Services            100,073.0
# Across Boundaries                                        100,001.23
# Wesley Clover Foundation                                  100,000.0
# Le Regroupement Des Gens D’Affaires De La Capit...        100,000.0
# Women’s Habitat Of Etobicoke                              100,000.0
#
# [2114 rows x 1 columns]

# %% [markdown]
# ### Binning data and breakdowns by industry

# %%
bracket_counts = pd.pivot_table(data, index="Earnings Bracket", columns="Sector", aggfunc='count', values="Year")

for label, col in bracket_counts.items():
    bracket_counts[label] = round((bracket_counts[label] / bracket_counts[label].sum()) * 100, 2)
    
bracket_counts
# Out:
# Sector            Colleges  Crown Agencies  Government of Ontario – Judiciary  \
# Earnings Bracket
# $100K - $155K        94.27           83.61                              43.97
# $155K - $210K         4.81           11.76                               6.19
# $210K - $265K          0.6            2.98                                1.9
# $265K - $320K         0.24            0.94                               3.81
# $320K - $1.7M         0.09            0.71                              44.13
#
# Sector            Government of Ontario – Legislative Assembly and Offices  \
# Earnings Bracket
# $100K - $155K                                                  78.3
# $155K - $210K                                                 15.57
# $210K - $265K                                                  5.19
# $265K - $320K                                                  0.47
# $320K - $1.7M                                                  0.47
#
# Sector            Government of Ontario – Ministries  \
# Earnings Bracket
# $100K - $155K                                  86.07
# $155K - $210K                                   8.15
# $210K - $265K                                   5.27
# $265K - $320K                                   0.23
# $320K - $1.7M                                   0.28
#
# Sector            Hospitals & Boards of Public Health  \
# Earnings Bracket
# $100K - $155K                                   91.61
# $155K - $210K                                    4.94
# $210K - $265K                                    1.26
# $265K - $320K                                    0.81
# $320K - $1.7M                                    1.38
#
# Sector            Municipalities & Services  Ontario Power Generation  \
# Earnings Bracket
# $100K - $155K                         92.05                     63.98
# $155K - $210K                          7.05                     27.62
# $210K - $265K                           0.7                      6.17
# $265K - $320K                          0.14                      1.15
# $320K - $1.7M                          0.06                      1.08
#
# Sector            Other Public Sector Employers  School Boards  Universities
# Earnings Bracket
# $100K - $155K                             83.79          99.18         55.25
# $155K - $210K                             10.11           0.73         33.65
# $210K - $265K                              3.25           0.07          8.19
# $265K - $320K                              2.05           0.01          1.88
# $320K - $1.7M                              0.79            0.0          1.03

# %%
universities = pd.pivot_table(data.loc[data["Sector"] == "Universities", :], index="Earnings Bracket", columns="Employer", aggfunc='count', values="Year")

for label, col in universities.items():
    universities[label] = round((universities[label] / universities[label].sum()) * 100, 2)

# %%
ministries = pd.pivot_table(data.loc[data["Sector"] == "Government of Ontario – Ministries", :], index="Earnings Bracket", columns="Employer", aggfunc='count', values="Year")

for label, col in ministries.items():
    ministries[label] = round((ministries[label] / ministries[label].sum()) * 100, 2)
    
ministries.to_clipboard()

# %%
municipalities = pd.pivot_table(data.loc[data["Sector"] == "Crown Agencies", :], index="Earnings Bracket", columns="Employer", aggfunc='count', values="Year")

for label, col in municipalities.items():
    municipalities[label] = round((municipalities[label] / municipalities[label].sum()) * 100, 2)
    
municipalities.transpose().sort_values("$100K - $155K", ascending=True).head(20).to_clipboard()

# %% [markdown]
# ### Top 10 earners

# %%
data.loc[:, "Name/Title"] = "**" + data.index + "**<br>" + data["Job Title"]

df_tops = (data
           .pivot_table(columns="Year", values="Salary", index=["Name/Title", "Employer"], aggfunc="min")
           .sort_values(2021, ascending=False)
           .head(50)
           )

df_tops.to_clipboard()

# %% [markdown]
# ### Ranges

# %%
data
# Out:
#                                                  Sector  Last Name First Name  \
# Name
# Kenneth Hartwick               Ontario Power Generation   Hartwick    Kenneth
# Dominique Miniere              Ontario Power Generation    Miniere  Dominique
# Sean Granville                 Ontario Power Generation  Granville       Sean
# Michael Martelli               Ontario Power Generation   Martelli    Michael
# Kevin Smith         Hospitals & Boards of Public Health      Smith      Kevin
# ...                                                 ...        ...        ...
# Nathalie Mouralian            Municipalities & Services  Mouralian   Nathalie
# Tony Dunn                 Other Public Sector Employers       Dunn       Tony
# Roderick Brereton         Other Public Sector Employers   Brereton   Roderick
# Farley Fridal             Other Public Sector Employers     Fridal     Farley
# Carla Neto                Other Public Sector Employers       Neto      Carla
#
#                          Salary  Benefits  \
# Name
# Kenneth Hartwick    1,628,246.0  7,539.84
# Dominique Miniere  1,523,518.84  3,922.56
# Sean Granville     1,064,429.42  2,632.32
# Michael Martelli   1,010,834.05   3,758.4
# Kevin Smith           845,092.2 87,153.64
# ...                         ...       ...
# Nathalie Mouralian    100,000.0       0.0
# Tony Dunn             100,000.0 23,297.82
# Roderick Brereton     100,000.0       0.0
# Farley Fridal         100,000.0       0.0
# Carla Neto            100,000.0  21,000.0
#
#                                                  Employer  \
# Name
# Kenneth Hartwick                 Ontario Power Generation
# Dominique Miniere                Ontario Power Generation
# Sean Granville                   Ontario Power Generation
# Michael Martelli                 Ontario Power Generation
# Kevin Smith                     University Health Network
# ...                                                   ...
# Nathalie Mouralian                        City Of Toronto
# Tony Dunn                        Wesley Clover Foundation
# Roderick Brereton   Urban Rez Solutions Social Enterprise
# Farley Fridal       Urban Rez Solutions Social Enterprise
# Carla Neto                   Women’s Habitat Of Etobicoke
#
#                                                             Job Title  Year  \
# Name
# Kenneth Hartwick                President and Chief Executive Officer  2021
# Dominique Miniere                              Chief Strategy Officer  2021
# Sean Granville      Chief Operations Officer and Chief Nuclear Off...  2021
# Michael Martelli                               Chief Projects Officer  2021
# Kevin Smith                     President and Chief Executive Officer  2021
# ...                                                               ...   ...
# Nathalie Mouralian                                Support Assistant C  2021
# Tony Dunn                                    Chief Operations Officer  2021
# Roderick Brereton                                  Executive Director  2021
# Farley Fridal                                      Executive Director  2021
# Carla Neto                                         Executive Director  2021
#
#                     _docID Earnings Bracket  \
# Name
# Kenneth Hartwick    126612    $320K - $1.7M
# Dominique Miniere   128750    $320K - $1.7M
# Sean Granville      126360    $320K - $1.7M
# Michael Martelli    128308    $320K - $1.7M
# Kevin Smith          64694    $320K - $1.7M
# ...                    ...              ...
# Nathalie Mouralian  104078    $100K - $155K
# Tony Dunn           134132    $100K - $155K
# Roderick Brereton   132871    $100K - $155K
# Farley Fridal       134563    $100K - $155K
# Carla Neto          137705    $100K - $155K
#
#                                                            Name/Title
# Name
# Kenneth Hartwick    **Kenneth Hartwick**<br>President and Chief Ex...
# Dominique Miniere     **Dominique Miniere**<br>Chief Strategy Officer
# Sean Granville      **Sean Granville**<br>Chief Operations Officer...
# Michael Martelli       **Michael Martelli**<br>Chief Projects Officer
# Kevin Smith         **Kevin Smith**<br>President and Chief Executi...
# ...                                                               ...
# Nathalie Mouralian      **Nathalie Mouralian**<br>Support Assistant C
# Tony Dunn                   **Tony Dunn**<br>Chief Operations Officer
# Roderick Brereton         **Roderick Brereton**<br>Executive Director
# Farley Fridal                 **Farley Fridal**<br>Executive Director
# Carla Neto                       **Carla Neto**<br>Executive Director
#
# [244248 rows x 11 columns]

# %%
sectors = data.groupby("Sector").count().loc[:, ["Last Name"]].sort_values("Last Name", ascending=False)

sectors
# Out:
#                                                     Last Name
# Sector
# School Boards                                           80434
# Municipalities & Services                               53835
# Hospitals & Boards of Public Health                     30571
# Universities                                            23096
# Government of Ontario – Ministries                      20319
# Crown Agencies                                           9824
# Other Public Sector Employers                            8731
# Ontario Power Generation                                 8520
# Colleges                                                 7864
# Government of Ontario – Judiciary                         630
# Government of Ontario – Legislative Assembly an...        424

# %%
sector_max = data.pivot_table(index="Sector", values="Salary", aggfunc="max")
sector_avg = data.pivot_table(index="Sector", values="Salary", aggfunc="median")
sector_total = data.pivot_table(index="Sector", values="Salary", aggfunc="sum")

sectors = pd.concat([sector_max, sector_avg, sector_total], axis=1)
sectors.columns = ["Max", "Average", "Total"]

sectors = sectors.sort_values("Total", ascending=False)

sectors.to_clipboard()

# %% [markdown]
# ### Carleton University

# %%
data.loc[data["Employer"] == "Carleton University", :].sort_values("Salary", ascending=False).to_clipboard()

# %% [markdown]
# ### Split by industry into different excel sheets

# %%
# categories = data_2020["Sector"].unique()
# sheets = []

# for category in categories:
#     df = data_2020.loc[data_2020["Sector"] == category, :]
#     df.loc[:, "Name/Title"] = "**" + df["Name"] + "**<br>" + df["Job Title"]
#     df = df.loc[:, ["Name/Title", "Employer", "Salary", "Benefits"]]
#     sheets.append(df)

# %%
# writer = pd.ExcelWriter('exports/sunshine_list.xlsx')

# for i, df in enumerate(sheets, 0):
#     df.to_excel(writer, index=False,sheet_name=f'{categories[i]}'[:30])

# writer.save()

# %% [markdown]
# ### Gender analysis

# %%
url = 'https://parseapi.back4app.com/classes/Complete_List_Names?limit=500000'
headers = {
    'X-Parse-Application-Id': 'zsSkPsDYTc2hmphLjjs9hz2Q3EXmnSxUyXnouj1I',
    'X-Parse-Master-Key': '4LuCXgPPXXO2sU5cXm6WwpwzaKyZpo3Wpj4G4xXK'
}
name_data = requests.get(url, headers=headers).json()["results"]
data2 = json.dumps(name_data)
names = pd.read_json(data2)

display(names)
# Out:
#           objectId      Name  Gender                 createdAt  \
# 0       lSxg9sIUv9      Will    male  2020-01-23T23:31:09.261Z
# 1       Ypp4vpokki     James    male  2020-01-23T23:31:09.241Z
# 2       tZYFQ1Yjyj    Samuel    male  2020-01-23T23:31:09.260Z
# 3       LxQmByBQ1y      John    male  2020-01-23T23:31:09.240Z
# 4       2S3LArF0dw    George    male  2020-01-23T23:31:09.241Z
# ...            ...       ...     ...                       ...
# 257995  kAzsJnXLBn      Diya  female  2020-01-23T23:43:40.706Z
# 257996  1Do0BIVl3n    Kenley  female  2020-01-23T23:43:40.706Z
# 257997  X5boZIpAnZ   Elianna  female  2020-01-23T23:43:40.706Z
# 257998  u6izCGBJUz     Iyana  female  2020-01-23T23:43:40.706Z
# 257999  xVrQ50GSI9  Carleigh  female  2020-01-23T23:43:40.706Z
#
#                        updatedAt
# 0       2020-01-23T23:31:09.261Z
# 1       2020-01-23T23:31:09.241Z
# 2       2020-01-23T23:31:09.260Z
# 3       2020-01-23T23:31:09.240Z
# 4       2020-01-23T23:31:09.241Z
# ...                          ...
# 257995  2020-01-23T23:43:40.706Z
# 257996  2020-01-23T23:43:40.706Z
# 257997  2020-01-23T23:43:40.706Z
# 257998  2020-01-23T23:43:40.706Z
# 257999  2020-01-23T23:43:40.706Z
#
# [258000 rows x 5 columns]

# %%
name_count = (names
              .value_counts(subset=["Name","Gender"])
              .reset_index()
              .pivot(columns="Gender", index="Name")
              .fillna(0)
              )

name_count.columns = name_count.columns.droplevel(0)

name_count["chance_male"] = name_count["male"] / (name_count["male"] + name_count["female"])
name_count["Gender"] = np.where(name_count['chance_male']>=0.65, 'Male', np.where(name_count['chance_male']<=0.35, 'Female', pd.NA))

gender_list = name_count[["Gender"]].reset_index()

display(gender_list)
# Out:
# Gender     Name  Gender
# 0         Aaden    Male
# 1       Aaliyah  Female
# 2         Aarav    Male
# 3         Aaron    Male
# 4            Ab    Male
# ...         ...     ...
# 6777       Zula  Female
# 6778     malece    Male
# 6779      maled    Male
# 6780    malesie    Male
# 6781       true    Male
#
# [6782 rows x 2 columns]

# %%
with_gender = data.merge(gender_list, left_on='First Name', right_on="Name", how="left").drop_duplicates()

with_gender = with_gender[["Name/Title", "Sector", "Job Title", "Employer", "Salary", "Benefits", "Earnings Bracket", "Gender"]]
with_gender["Gender"] = with_gender["Gender"].fillna("Unknown")

with_gender.head(3)
# Out:
#                                           Name/Title  \
# 0  **Kenneth Hartwick**<br>President and Chief Ex...
# 1    **Dominique Miniere**<br>Chief Strategy Officer
# 2  **Sean Granville**<br>Chief Operations Officer...
#
#                      Sector  \
# 0  Ontario Power Generation
# 1  Ontario Power Generation
# 2  Ontario Power Generation
#
#                                            Job Title  \
# 0              President and Chief Executive Officer
# 1                             Chief Strategy Officer
# 2  Chief Operations Officer and Chief Nuclear Off...
#
#                    Employer       Salary  Benefits Earnings Bracket   Gender
# 0  Ontario Power Generation  1,628,246.0  7,539.84    $320K - $1.7M     Male
# 1  Ontario Power Generation 1,523,518.84  3,922.56    $320K - $1.7M  Unknown
# 2  Ontario Power Generation 1,064,429.42  2,632.32    $320K - $1.7M     Male

# %%
avg_salary = round(with_gender.pivot_table(index="Gender", values="Salary", aggfunc="mean"),0)
count = round(with_gender.pivot_table(index="Gender", values="Name/Title", aggfunc="count"),0)
sum = round(with_gender.pivot_table(index="Gender", values="Salary", aggfunc="sum"),0)
median = round(with_gender.pivot_table(index="Gender", values="Salary", aggfunc="median"),0)

pd.concat([avg_salary, count, sum, median], axis=1)
# Out:
#            Salary  Name/Title           Salary    Salary
# Gender
# Female  117,920.0       91098 10,742,236,236.0 106,625.0
# Male    128,700.0       77276  9,945,439,904.0 116,667.0
# Unknown 125,673.0       75874  9,535,344,526.0 112,721.0
